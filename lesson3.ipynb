# %% [markdown]
# ### Чтение из текствового файла

# %%
f = open('test.dat')
lines = f.readlines()
x = []
y = []
for li in lines:
    z = li.split()
    print(z)
    x += [float(z[0])]
    y += [float(z[1])]

x, y
# Out:
# ['1', '2.1']
# ['2', '1.2']
# ['3', '4.5']
# ([1.0, 2.0, 3.0], [2.1, 1.2, 4.5])

# %%
with open('test.dat') as f :
    data = [[ float(v) for v in l.split()] for l in f.readlines()]
    x = [z[0] for z in data]
    y = [z[1] for z in data]

x, y , data
# Out:
# ([1.0, 2.0, 3.0], [2.1, 1.2, 4.5], [[1.0, 2.1], [2.0, 1.2], [3.0, 4.5]])

# %%
from matplotlib import pyplot as plt

plt.plot(x, y)
plt.show()
